# %%
import pandas as pd 
from pprint import pprint

# %%
database_location = "/Users/pyuvraj/CCPP/data_for_profit_from_stock/stock_per_category"
database_name = "all_stocks_data_with_ranking.csv"

# %%
database = pd.read_csv(database_location + "/" + database_name)

# %%
list(database)
# Out:
# ['Unnamed: 0',
#  'Symbol',
#  'Name',
#  'Last Sale',
#  'Net Change',
#  '% Change',
#  'Market Cap',
#  'Country',
#  'IPO Year',
#  'Volume',
#  'Sector',
#  'Industry',
#  'stock_name',
#  'stock_growth']

# %%
del database['Unnamed: 0']

# %%
print(database)
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $155.70
# 1        AA                    Alcoa Corporation Common Stock     $40.71
# 2       AAL          American Airlines Group Inc. Common Stock    $21.02
# 3      AAMC               Altisource Asset Management Corp Com    $15.64
# 4      AAME         Atlantic American Corporation Common Stock     $4.53
# ...     ...                                                ...       ...
# 3690    ZNH  China Southern Airlines Company Limited Common...    $25.78
# 3691   ZSAN             Zosano Pharma Corporation Common Stock   $0.7736
# 3692    ZTR                      Virtus Total Return Fund Inc.     $9.84
# 3693    ZUO                    Zuora Inc. Class A Common Stock    $16.18
# 3694   ZYNE          Zynerba Pharmaceuticals Inc. Common Stock     $4.44
#
#       Net Change % Change    Market Cap        Country  IPO Year    Volume  \
# ...

# %%
g = database.groupby(['Industry'])

# %%
dir(g.Industry)
# Out:
# ['__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_agg_examples_doc',
#  '_agg_general',
#  '_aggregate',
#  '_aggregate_multiple_funcs',
#  '_aggregate_named',
#  '_apply_allowlist',
#  '_apply_filter',
#  '_apply_to_column_groupbys',
#  '_assure_grouper',
#  '_bool_agg',
#  '_builtin_table',
#  '_concat_objects',
#  '_constructor',
#  '_cumcount_array',
#  '_cython_agg_general',
#  '_cython_table',
#  '_cython_transform',
# ...

# %%
database.sort_values(['stock_growth'], ascending=True).groupby(['Sector']).head(3)
# Out:
#      Symbol                                               Name Last Sale  \
# 610     CEI                    Camber Energy Inc. Common Stock   $0.4606
# 1719   INPX                               Inpixon Common Stock     $1.03
# 3040    SLS       SELLAS Life Sciences Group Inc. Common Stock     $9.40
# 295    AVGR                          Avinger Inc. Common Stock     $0.94
# 3286   TOPS                        TOP Ships Inc. Common Stock     $1.31
# 1786   JAGX                    Jaguar Health Inc. Common Stock     $1.36
# 3488   VISL             Vislink Technologies Inc. Common Stock     $2.16
# 2515   OPTT         Ocean Power Technologies Inc. Common Stock     $1.92
# 2728   PSHG            Performance Shipping Inc. Common Shares     $4.58
# 1968   LMFA               LM Funding America Inc. Common Stock     $4.48
# 439    BLIN               Bridgeline Digital Inc. Common Stock     $5.00
# 3674   YTEN               Yield10 Bioscience Inc. Common Stock     $7.47
# ...

# %%
pprint(set(database['Industry']))
# Out:
# {'Accident &Health Insurance',
#  'Advertising',
#  'Aerospace',
#  'Agricultural Chemicals',
#  'Air Freight/Delivery Services',
#  'Aluminum',
#  'Apparel',
#  'Assisted Living Services',
#  'Auto Manufacturing',
#  'Auto Parts:O.E.M.',
#  'Automotive Aftermarket',
#  'Banks',
#  'Beverages (Production/Distribution)',
#  'Biotechnology: Biological Products (No Diagnostic Substances)',
#  'Biotechnology: Commercial Physical & Biological Resarch',
#  'Biotechnology: Electromedical & Electrotherapeutic Apparatus',
#  'Biotechnology: In Vitro & In Vivo Diagnostic Substances',
#  'Biotechnology: Laboratory Analytical Instruments',
#  'Books',
#  'Broadcasting',
#  'Building Materials',
#  'Building Products',
#  'Building operators',
#  'Business Services',
#  'Catalog/Specialty Distribution',
#  'Clothing/Shoe/Accessory Stores',
#  'Coal Mining',
#  'Commercial Banks',
#  'Computer Communications Equipment',
#  'Computer Manufacturing',
#  'Computer Software: Prepackaged Software',
# ...

# %%
growth_per_Industry = database.groupby('Industry').mean()

# %%
growth_per_Industry.sort_values(by=['stock_growth'], ascending=False).head(10)
# Out:
#                                                     Net Change    Market Cap  \
# Industry
# Hotels/Resorts                                        0.476818  1.118839e+10
# Finance: Consumer Services                            0.820345  3.849658e+09
# Internet and Information Services                    -1.000000  6.717169e+11
# Auto Parts:O.E.M.                                     0.729688  5.920833e+09
# Trusts Except Educational Religious and Charitable    0.006029  4.404242e+08
# Business Services                                    -0.660122  2.946754e+10
# Other Consumer Services                              -1.312970  6.910390e+09
# Ophthalmic Goods                                     -1.850000  2.097119e+10
# Automotive Aftermarket                                0.030000  7.249234e+09
# Metal Fabrications                                    0.436219  6.102026e+09
#
#                                                        IPO Year        Volume  \
# Industry
# ...

# %%
database.sort_values(['stock_growth'], ascending=False).head(40)
# Out:
#      Symbol                                               Name Last Sale  \
# 1827    JPT  Nuveen Preferred and Income 2022 Term Fund Com...    $25.35
# 2536    OSW         OneSpaWorld Holdings Limited Common Shares    $10.46
# 3567    WEI  Weidai Ltd. American depositary shares each  r...     $1.04
# 3335     TT                             Trane Technologies plc   $197.00
# 2103    MGY  Magnolia Oil & Gas Corporation Class A Common ...    $14.48
# 1397    GHG  GreenTree Hospitality Group Ltd. American depo...     $9.54
# 738     CNF  CNFinance Holdings Limited American Depositary...     $4.24
# 1874    KLR                          Kaleyra Inc. Common Stock     $9.94
# 2554    PAE              PAE Incorporated Class A Common Stock     $8.27
# 2075    MEC     Mayville Engineering Company Inc. Common Stock    $17.08
# 2803    RCM                           R1 RCM Inc. Common Stock    $20.80
# 1732   INVH                 Invitation Homes Inc. Common Stock    $40.12
# ...
