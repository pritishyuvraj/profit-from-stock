# %%
import pandas as pd

# %%
database = pd.read_csv('/Users/pyuvraj/CCPP/data_for_profit_from_stock/stock_per_category/all_stocks_data_with_ranking_v2.csv')

# %%
database
# Out:
#       Unnamed: 0 Symbol                                              Name  \
# 0              0      A            Agilent Technologies Inc. Common Stock
# 1              1     AA                   Alcoa Corporation Common Stock
# 2              2   AACG  ATA Creativity Global American Depositary Shares
# 3              3    AAL         American Airlines Group Inc. Common Stock
# 4              4   AAMC              Altisource Asset Management Corp Com
# ...          ...    ...                                               ...
# 4761        4761    ZTS                  Zoetis Inc. Class A Common Stock
# 4762        4762    ZUO                   Zuora Inc. Class A Common Stock
# 4763        4763    ZVO                           Zovio Inc. Common Stock
# 4764        4764   ZYNE         Zynerba Pharmaceuticals Inc. Common Stock
# 4765        4765   ZYXI                           Zynex Inc. Common Stock
#
#      Last Sale  Net Change % Change    Market Cap        Country  IPO Year  \
# ...

# %%
database.sort_values("overall_profit", ascending=False)
# Out:
#       Unnamed: 0 Symbol                                               Name  \
# 1310        1310    DTW  DTE Energy Company 2017 Series E 5.25% Junior ...
# 3261        3261    OSW         OneSpaWorld Holdings Limited Common Shares
# 2372        2372    JPT  Nuveen Preferred and Income 2022 Term Fund Com...
# 567          567   BILL                Bill.com Holdings Inc. Common Stock
# 4316        4316     TT                             Trane Technologies plc
# ...          ...    ...                                                ...
# 4752        4752   ZLAB         Zai Lab Limited American Depositary Shares
# 4753        4753     ZM  Zoom Video Communications Inc. Class A Common ...
# 4756        4756    ZOM                       Zomedica Corp. Common Shares
# 4757        4757     ZS                          Zscaler Inc. Common Stock
# 4763        4763    ZVO                            Zovio Inc. Common Stock
#
# ...
