# %%
import pandas as pd

# %%
folder_location = '/Users/pyuvraj/CCPP/data_for_profit_from_stock/stock_per_category'
file_name = 'all_stocks_data_with_ranking_v3.csv'
database = pd.read_csv(folder_location + '/' + file_name)

# %%
database
# Out:
#      Unnamed: 0 Symbol                                            Name  \
# 0             0   AAPL                         Apple Inc. Common Stock
# 1             1   ADBE                         Adobe Inc. Common Stock
# 2             2   ADSK                      Autodesk Inc. Common Stock
# 3             3   ADUS         Addus HomeCare Corporation Common Stock
# 4             4    AJG          Arthur J. Gallagher & Co. Common Stock
# ..          ...    ...                                             ...
# 142         142    WNS   WNS (Holdings) Limited Sponsored ADR (Jersey)
# 143         143    WST  West Pharmaceutical Services Inc. Common Stock
# 144         144   ZNGA                 Zynga Inc. Class A Common Stock
# 145         145    ZTS                Zoetis Inc. Class A Common Stock
# 146         146   ZYXI                         Zynex Inc. Common Stock
#
#     Last Sale  Net Change  % Change    Market Cap        Country  IPO Year  \
# ...

# %%
database.sort_values(['overall_profit', '2020_profit'], ascending=[0, 0])
# Out:
#      Unnamed: 0 Symbol                                        Name Last Sale  \
# 61           61   FRHC          Freedom Holding Corp. Common Stock    $64.56
# 52           52    EQX            Equinox Gold Corp. Common Shares     $6.33
# 146         146   ZYXI                     Zynex Inc. Common Stock    $14.89
# 55           55   FATE         Fate Therapeutics Inc. Common Stock    $95.42
# 47           47   EHTH                   eHealth Inc. Common Stock    $51.15
# ..          ...    ...                                         ...       ...
# 21           21    BKI             Black Knight Inc. Common Stock     $78.44
# 70           70      J  Jacobs Engineering Group Inc. Common Stock   $128.89
# 31           31   CDMO          Avid Bioservices Inc. Common Stock    $26.01
# 106         106    PLD                  Prologis Inc. Common Stock   $129.71
# 72           72    KSU           Kansas City Southern Common Stock   $271.77
#
# ...

# %%
print(database)
# Out:
#      Unnamed: 0 Symbol                                            Name  \
# 0             0   AAPL                         Apple Inc. Common Stock
# 1             1   ADBE                         Adobe Inc. Common Stock
# 2             2   ADSK                      Autodesk Inc. Common Stock
# 3             3   ADUS         Addus HomeCare Corporation Common Stock
# 4             4    AJG          Arthur J. Gallagher & Co. Common Stock
# ..          ...    ...                                             ...
# 142         142    WNS   WNS (Holdings) Limited Sponsored ADR (Jersey)
# 143         143    WST  West Pharmaceutical Services Inc. Common Stock
# 144         144   ZNGA                 Zynga Inc. Class A Common Stock
# 145         145    ZTS                Zoetis Inc. Class A Common Stock
# 146         146   ZYXI                         Zynex Inc. Common Stock
#
#     Last Sale  Net Change  % Change    Market Cap        Country  IPO Year  \
# ...

# %%
database.groupby(['Sector']).mean()
# Out:
#                        Unnamed: 0  Net Change    Market Cap     IPO Year  \
# Sector
# Basic Industries        60.833333    0.630000  1.432250e+10  2002.500000
# Capital Goods           80.647059   -0.456471  3.489169e+10  2002.666667
# Consumer Durables       67.000000   11.320000  2.619761e+10  2010.000000
# Consumer Non-Durables   66.500000   -1.580000  2.090642e+10  2004.000000
# Consumer Services       73.588235   -1.890588  2.930702e+10  2005.416667
# Energy                  61.000000    0.220000  3.773094e+09          NaN
# Finance                 50.444444    1.035556  2.576440e+10  2012.250000
# Health Care             83.833333   -1.245333  1.362651e+10  2009.210526
# Miscellaneous           75.357143    0.458571  9.287430e+10  1999.750000
# Public Utilities        50.666667    0.090000  5.424283e+10  1998.000000
# Technology              69.711111    0.101111  1.489097e+11  2005.147059
# Transportation          85.000000    0.290000  2.817367e+10  1991.000000
#
# ...

# %%
folder_location = '/Users/pyuvraj/CCPP/data_for_profit_from_stock/stock_per_category'
file_name = 'all_stocks_data_with_ranking_v2.csv'
database = pd.read_csv(folder_location + '/' + file_name)

# %%
database.groupby(['Sector']).mean()
# Out:
#                         Unnamed: 0  Net Change    Market Cap     IPO Year  \
# Sector
# Basic Industries       2561.044053    0.417345  8.819153e+09  2009.111111
# Capital Goods          2437.509284   -0.053217  1.211010e+10  2006.680000
# Consumer Durables      2243.011364    0.297510  5.825538e+09  2009.325581
# Consumer Non-Durables  2501.846995    0.219056  1.834930e+10  2007.558824
# Consumer Services      2352.481301   -0.139359  1.374150e+10  2008.777049
# Energy                 2520.412844    0.179668  9.148919e+09  2012.171429
# Finance                2294.816327    0.526547  5.519997e+09  2007.310292
# Health Care            2295.068096   -0.393047  9.091526e+09  2012.747454
# Miscellaneous          2447.111842   -0.047863  1.907260e+10  2009.453333
# Public Utilities       2407.915842   -0.072972  1.288708e+10  2011.960526
# Technology             2499.418966   -0.097921  3.226487e+10  2007.868020
# Transportation         2491.377358   -0.093345  9.973542e+09  2006.410714
# ...

# %%
database[database.Sector == 'Consumer Durables'].sort_values(by=['overall_profit'], ascending=False)
# Out:
#       Unnamed: 0 Symbol                                               Name  \
# 4545        4545    VRT           Vertiv Holdings LLC Class A Common Stock
# 518          518     BE      Bloom Energy Corporation Class A Common Stock
# 857          857    CGC            Canopy Growth Corporation Common Shares
# 3179        3179   OESX             Orion Energy Systems Inc. Common Stock
# 1875        1875   GNRC                Generac Holdlings Inc. Common Stock
# ...          ...    ...                                                ...
# 2062        2062   HOTH                Hoth Therapeutics Inc. Common Stock
# 4152        4152   TBIO                    Translate Bio Inc. Common Stock
# 4201        4201   TFFP              TFF Pharmaceuticals Inc. Common Stock
# 4239        4239   TLRY                  Tilray Inc. Class 2 Common Stock
# 4496        4496   VIOT  Viomi Technology Co. Ltd American Depositary S...
#
# ...

# %%
database.sort_values(by=['overall_profit'], ascending=False)
# Out:
#       Unnamed: 0 Symbol                                               Name  \
# 1310        1310    DTW  DTE Energy Company 2017 Series E 5.25% Junior ...
# 3261        3261    OSW         OneSpaWorld Holdings Limited Common Shares
# 2372        2372    JPT  Nuveen Preferred and Income 2022 Term Fund Com...
# 567          567   BILL                Bill.com Holdings Inc. Common Stock
# 4316        4316     TT                             Trane Technologies plc
# ...          ...    ...                                                ...
# 4752        4752   ZLAB         Zai Lab Limited American Depositary Shares
# 4753        4753     ZM  Zoom Video Communications Inc. Class A Common ...
# 4756        4756    ZOM                       Zomedica Corp. Common Shares
# 4757        4757     ZS                          Zscaler Inc. Common Stock
# 4763        4763    ZVO                            Zovio Inc. Common Stock
#
# ...

# %%
database['overall_profit_column_avg'] = (database['2017_profit'] + database['2018_profit'] + database['2019_profit'] + database['2020_profit']) / 4

# %%
database.sort_values(by=['overall_profit_column_avg'], ascending=False)
# Out:
#       Unnamed: 0 Symbol                                               Name  \
# 2372        2372    JPT  Nuveen Preferred and Income 2022 Term Fund Com...
# 3261        3261    OSW         OneSpaWorld Holdings Limited Common Shares
# 4592        4592    WEI  Weidai Ltd. American depositary shares each  r...
# 4316        4316     TT                             Trane Technologies plc
# 4002        4002    SPT             Sprout Social Inc Class A Common Stock
# ...          ...    ...                                                ...
# 4752        4752   ZLAB         Zai Lab Limited American Depositary Shares
# 4753        4753     ZM  Zoom Video Communications Inc. Class A Common ...
# 4756        4756    ZOM                       Zomedica Corp. Common Shares
# 4757        4757     ZS                          Zscaler Inc. Common Stock
# 4763        4763    ZVO                            Zovio Inc. Common Stock
#
# ...

# %%
database.groupby(by='overall_profit').nlargest(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-3bbd8dcc68ea> in <module>
# ----> 1 database.groupby(by='overall_profit').nlargest(3)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'nlargest'

# %%
temp = database.groupby('Sector')['overall_profit'].nlargest(3)

# %%
print(temp)
# Out:
# Sector
# Basic Industries       1467      4472.904954
#                        2861       585.417608
#                        236        290.887025
# Capital Goods          4316     86692.639232
#                        3511     16242.328958
#                        1431      1890.110599
# Consumer Durables      4545      2730.747208
#                        518       1308.827928
#                        857        467.849604
# Consumer Non-Durables  1072       247.703663
#                        2473       230.777810
#                        1702       230.585864
# Consumer Services      3261    302509.677583
#                        1825     68420.554764
#                        3608     33139.198973
# Energy                 2739     26543.351938
#                        1719     12461.223569
#                        672       2407.046333
# Finance                2372    277270.298639
#                        4592     41814.286566
#                        980      19286.675934
# ...

# %%
from pandas.io import sql
import MySQLdb

# %%
con = MySQLdb.connect(host="localhost", user="root", passwd="", db="profit_from_stock")

# %%
database.to_sql(con=con, name="profit_for_stock_full_database", if_exists='replace')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:2605: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/MySQLdb/cursors.py in execute(self, query, args)
#     200             try:
# --> 201                 query = query % args
#     202             except TypeError as m:
#
# TypeError: not all arguments converted during bytes formatting
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqlconnector://root:@localhost/profit_from_stock')

# %%
database.to_sql(con=engine, name="profit_for_stock_full_database", if_exists='replace')
